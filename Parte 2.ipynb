# %%
import sqlite3
from sqlite3 import Error

import pandas as pd

# %%
con = sqlite3.connect('sql-murder-mystery.db')

# %%
cursor = con.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('crime_scene_report',), ('drivers_license',), ('person',), ('facebook_event_checkin',), ('interview',), ('get_fit_now_member',), ('get_fit_now_check_in',), ('income',), ('solution',)]

# %%
query = "SELECT * from crime_scene_report WHERE date = 20180115 AND type = 'murder' ;"
murders = pd.read_sql(query,con)
murders
# Out:
#        date    type                                        description  \
# 0  20180115  murder                  Life? Dont talk to me about life.
# 1  20180115  murder  Mama, I killed a man, put a gun against his he...
# 2  20180115  murder  Security footage shows that there were 2 witne...
#
#        city
# 0    Albany
# 1      Reno
# 2  SQL City

# %%
query = "SELECT * from 'facebook_event_checkin' WHERE date = 20180115 ;"
person = pd.read_sql(query,con)
person
# Out:
#     person_id  event_id                                         event_name  \
# 0       56269      1753  "I just need enough to tide me over until I ne...
# 1       12272      2831                            Kinkler's Second Law:\n
# 2       94218      1200  If a listener nods his head when you're explai...
# 3       73091       104                                          "Diet."\n
# 4       20227      2513  It seems like the less a statesman amounts to,...
# 5       29596      6072                                    -- Mark Twain\n
# 6       43451      5155                                             eat.\n
# 7       71108      1056               effort to teach them good manners.\n
# 8       39959      2513  Democracy is a form of government that substit...
# 9       38423      8548                                     pedestrians.\n
# 10      60433      3204                                          handle.\n
# ...

# %%
query = "SELECT * from interview ;"
person = pd.read_sql(query,con)
person
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]
